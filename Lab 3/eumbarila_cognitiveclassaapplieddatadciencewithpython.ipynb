# %% [markdown]
# **Link perfil de LinkedIn:**
#
# www.linkedin.com/in/esteban-umba

# %% [markdown]
# **Cerificaciones del perfil:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Certificado Python 101 for Data Science:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Certificado Data Analysis with Python:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Certificado Data Visualization with Python:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
